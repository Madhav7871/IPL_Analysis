# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhav7871/IPL_Analysis/blob/main/IPL_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - IPL ANALYSIS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - Madhav Kalra**

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# ##Project Overview
# The Indian Premier League (IPL) is globally celebrated as one of the most competitive, high-octane T20 cricket tournaments, where batting styles constantly evolve to match aggressive modern standards. This Exploratory Data Analysis (EDA) project, titled IPL ANALYSIS, offers a comprehensive, data-driven deep dive into the batting dynamics of the IPL 2025 season. Conducted as an individual project, the primary objective is to look past basic leaderboards and thoroughly examine player performances, uncovering the underlying patterns that defined batting success, consistency, and scoring efficiency across various franchises during the tournament.
#
# ##About the Dataset
# The core foundation of this analysis relies on a structured dataset named IPL2025Batters.csv. This dataset tracks a comprehensive group of 156 batsmen who featured in the tournament, recording their contributions across 14 essential cricketing parameters. It includes basic categorical identifiers like Player Name and Team affiliation, alongside volume metrics such as Matches played, Innings (Inn), and Balls Faced (BF). Crucial performance-quality indicators like total Runs, Not Outs (No), Highest Score (HS), Batting Average (AVG), and Strike Rate (SR) are prominently featured. Furthermore, the dataset logs milestone achievements and boundary profiles using dedicated metrics for centuries (100s), half-centuries (50s), fours (4s), and sixes (6s), providing a robust framework for multi-dimensional player profiling.
#
# ##Conclusion
# Ultimately, this project transforms dense tabular statistics into highly scannable and visually engaging insights. By evaluating individual and team-level metrics simultaneously, the analysis offers a polished, comprehensive summary of the IPL 2025 batting landscape, establishing a clear framework for understanding what drives elite T20 batting performance.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The Indian Premier League (IPL) is a fast-paced, high-stakes tournament where batting dynamics heavily dictate team success. However, evaluating player performance by relying solely on traditional, surface-level metrics—such as aggregate runs—fails to provide a complete picture of a batter's true impact. The challenge lies in making sense of raw, unorganized statistics from the IPL 2025 season to understand player efficiency in the modern T20 format. There is a critical need to systematically analyze a combination of metrics, including strike rates, batting averages, boundary-hitting frequencies, and milestone conversions, to accurately identify which players were the most impactful, which franchises possessed the strongest batting depth, and what overarching statistical trends defined the season.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this Exploratory Data Analysis (EDA) is to transform raw IPL 2025 batting data into strategic, actionable insights. By meticulously analyzing individual and team-level performances, the goal is to:
#
# Evaluate Player Value and Impact: Identify high-value players who effectively combine consistency (high batting average) with aggressive scoring (high strike rate). This intelligence is crucial for franchise management to inform future auction strategies, player retention, and scouting decisions.
#
# Assess Franchise Batting Strength: Compare the collective batting firepower across different teams to pinpoint strengths, vulnerabilities, and dependencies within specific squad lineups.
#
# Uncover Modern T20 Strategies: Analyze boundary percentages (fours and sixes) and milestone achievements to understand how elite batters maximize scoring in the shortest format of the game.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
dataset = pd.read_csv('/content/drive/MyDrive/data/IPL2025Batters.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
dataset.head()
# Out:
#          Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0      Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1  Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2        Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3       Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4     Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38
# 2     0    8  66  19
# 3     0    6  62  24
# 4     1    6  56  37

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
dataset.shape
# Out:
# (156, 14)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  156 non-null    object
#  1   Team         156 non-null    object
#  2   Runs         156 non-null    int64
#  3   Matches      156 non-null    int64
#  4   Inn          156 non-null    int64
#  5   No           156 non-null    int64
#  6   HS           156 non-null    object
#  7   AVG          156 non-null    object
#  8   BF           156 non-null    int64
#  9   SR           156 non-null    float64
#  10  100s         156 non-null    int64
#  11  50s          156 non-null    int64
#  12  4s           156 non-null    int64
#  13  6s           156 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 17.2+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
dataset.isnull().sum()
# Out:
# Player Name    0
# Team           0
# Runs           0
# Matches        0
# Inn            0
# No             0
# HS             0
# AVG            0
# BF             0
# SR             0
# 100s           0
# 50s            0
# 4s             0
# 6s             0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(dataset.isnull(), cbar=False, cmap='viridis')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset consists of 156 rows and 14 columns, capturing the individual batting statistics of players during the IPL 2025 season. It includes a mix of categorical and numerical features such as Player Name, Team, Runs, Matches, Innings (Inn), Not Outs (No), Highest Score (HS), Average (AVG), Balls Faced (BF), Strike Rate (SR), along with boundary metrics like 100s, 50s, 4s, and 6s. Upon initial inspection, the data is exceptionally clean, containing zero missing or null values and no duplicate records. While most performance metrics are appropriately formatted as integer or float numerical types, the 'Highest Score' (HS) column is currently classified as an object data type due to the presence of the '*' symbol used to denote not-out innings, which will require cleaning for further numerical analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
dataset.columns
# Out:
# Index(['Player Name', 'Team', 'Runs', 'Matches', 'Inn', 'No', 'HS', 'AVG',
#        'BF', 'SR', '100s', '50s', '4s', '6s'],
#       dtype='object')

# %%
# Dataset Describe
dataset.describe()
# Out:
#              Runs     Matches         Inn          No          BF          SR  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   161.320513    9.865385    7.153846    1.634615  105.673077  134.394103
# std    180.352772    4.757455    4.810142    1.658163  112.191838   57.237148
# min      1.000000    1.000000    1.000000    0.000000    1.000000   25.000000
# 25%     10.750000    6.000000    2.750000    0.000000   12.000000  100.000000
# 50%     93.500000   11.000000    6.000000    1.000000   63.500000  140.005000
# 75%    254.250000   14.000000   12.000000    3.000000  164.750000  162.707500
# max    759.000000   17.000000   17.000000    7.000000  486.000000  400.000000
#
#              100s         50s          4s          6s
# count  156.000000  156.000000  156.000000  156.000000
# mean     0.057692    0.916667   14.391026    8.294872
# std      0.233912    1.590124   17.778774    9.515500
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Player Name: The name of the batsman.
#
# Team: The IPL franchise the player represents.
#
# Runs: Total runs scored by the player in the season.
#
# Matches: Total number of matches the player participated in.
#
# Inn: Number of innings the player actually batted in.
#
# No: Number of times the player remained "Not Out" at the end of an innings.
#
# HS: Highest Score achieved by the player in a single match (an asterisk * denotes they were not out).
#
# AVG: Batting Average (Total Runs divided by the number of times they were dismissed).
#
# BF: Total Balls Faced by the player.
#
# SR: Strike Rate (Average number of runs scored per 100 balls faced).
#
# 100s: Total number of centuries (scores of 100 or more) hit.
#
# 50s: Total number of half-centuries (scores between 50 and 99) hit.
#
# 4s: Total number of fours hit by the player.
#
# 6s: Total number of sixes hit by the player.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
dataset.nunique()
# Out:
# Player Name    156
# Team            10
# Runs           112
# Matches         17
# Inn             17
# No               8
# HS             105
# AVG            118
# BF             109
# SR             134
# 100s             2
# 50s              8
# 4s              49
# 6s              32
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
dataset['HS'] = dataset['HS'].astype(str).str.replace('*', '')
dataset['HS'] = pd.to_numeric(dataset['HS'])

dataset['AVG'] = dataset['AVG'].astype(str).str.replace('-', '0')
dataset['AVG'] = pd.to_numeric(dataset['AVG'])

dataset.drop_duplicates(inplace=True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Highest Score (HS) Standardization: The raw HS column contained an asterisk * symbol to indicate that a batter remained not out during their highest-scoring innings. This forced the column to be treated as text (object). I stripped the * characters and converted the entire column into an integer numerical type so it can be used for mathematical operations and plotting.
#
# Batting Average (AVG) Correction: Some batsmen did not get dismissed or did not bat enough to have a calculated average, resulting in a hyphen (-) in the raw data. I replaced these hyphens with 0 and converted the column to a float numerical type to ensure smooth computations and prevent runtime errors during plotting.
#
# Deduplication: A duplicate check was executed across the entire dataset, and drop_duplicates() was run to guarantee that every row uniquely represents a single player with no redundant entries.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
import matplotlib.pyplot as plt
import seaborn as sns

# Setting a global dark background style
plt.style.use('dark_background')

# Initialize figure and set custom dark facecolors for a modern UI look
fig, ax = plt.subplots(figsize=(14, 7))
fig.patch.set_facecolor('#121212')
ax.set_facecolor('#121212')

# Creating a histogram with KDE using high-energy neon colors
sns.histplot(dataset['Runs'], bins=25, kde=True,
             color='#00E5FF', edgecolor='#121212', alpha=0.7,
             line_kws={'linewidth': 3, 'color': '#FF007F'}, ax=ax)

# Enhancing aesthetics and labels with distinct white/grey tones
plt.title('Univariate Analysis: Distribution of Total Runs Scored (IPL 2025)', fontsize=18, fontweight='bold', color='white', pad=15)
plt.xlabel('Total Runs Scored', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)
plt.ylabel('Frequency (Number of Players)', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)

# Adding subtle gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.2, color='white')

# Refining the axes borders
sns.despine(ax=ax, top=True, right=True)
ax.spines['left'].set_color('#333333')
ax.spines['bottom'].set_color('#333333')
ax.tick_params(colors='#E0E0E0')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Histogram paired with a Kernel Density Estimate (KDE) curve is the absolute best chart for univariate continuous data. It allows us to immediately see the shape, spread, and skewness of the runs scored across the entire dataset of 156 players, showing exactly where the majority of players fall.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The distribution is heavily right-skewed (a long tail towards the right). The massive peak on the left indicates that the vast majority of players scored between 0 and 100 runs throughout the tournament (these are primarily specialist bowlers, lower-order batters, or bench players who played very few matches). Conversely, the long tail shows that players scoring 400+ runs are exceedingly rare, highlighting the scarcity of elite top-order run accumulators.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: Yes. Franchise owners and talent scouts can use this to understand market scarcity. Since 400+ run scorers are statistically rare, franchises can justify allocating premium auction budgets to retain or buy these consistent top-order players, ensuring steady batting performances.
#
# Negative Growth/Risk: A key negative insight here is squad fragility. If a team's total run composition is dominated by just 1 or 2 players sitting in the far right tail, an injury to them could collapse the entire team's performance, as the vast majority of the squad statistically sits in the low-scoring bracket. Teams must ensure they have a balanced middle order rather than just relying on outliers.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(14, 7))
fig.patch.set_facecolor('#0f0f13')
ax.set_facecolor('#0f0f13')

# Violin plot for Strike Rate distribution
sns.violinplot(x=dataset['SR'], color='#b800ff', inner="quartile",
               linewidth=2, linecolor='#00ffcc', ax=ax, alpha=0.8)

plt.title('Univariate Analysis: Density & Spread of Strike Rates', fontsize=18, fontweight='bold', color='white', pad=15)
plt.xlabel('Strike Rate (Runs per 100 Balls)', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)

plt.grid(axis='x', linestyle=':', alpha=0.3, color='#00ffcc')
sns.despine(left=True, top=True, right=True)
ax.tick_params(colors='#E0E0E0')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Violin Plot is an excellent choice here because it combines the summary statistics of a box plot with the density estimation of a histogram. It allows us to see exactly where the bulk of the players' strike rates are concentrated (the widest part of the "violin") while also showing the extreme outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The visual highlights the median strike rate of the tournament and reveals the shape of the data. Most players cluster around a baseline strike rate (likely around 120-140). The long, thin tail extending to the right indicates the rare, ultra-aggressive hitters who possess exceptionally high strike rates, separating the standard batters from the true impact finishers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: Franchises can use this to identify undervalued players. If a player sits in the higher percentile (the right side of the violin) but isn't a massive household name, they represent a high-ROI (Return on Investment) target for auctions.
#
# Negative Growth/Risk: A team heavily populated by players in the thick, lower-end belly of this plot will suffer negative growth. In modern T20 cricket, accumulating runs too slowly loses matches. Identifying and releasing these slow scorers is crucial to avoiding stagnant team performance.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(14, 8))
fig.patch.set_facecolor('#1a1a1a')
ax.set_facecolor('#1a1a1a')

# Getting Top 10 Run Scorers
top_10_batters = dataset.nlargest(10, 'Runs')

# Horizontal bar chart with a fiery gradient theme
sns.barplot(x='Runs', y='Player Name', data=top_10_batters,
            palette='YlOrRd_r', edgecolor='#ffffff', ax=ax)

plt.title('Bivariate Analysis: Top 10 Run Scorers (Orange Cap Contenders)', fontsize=18, fontweight='bold', color='white', pad=15)
plt.xlabel('Total Runs', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)
plt.ylabel('Player Name', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)

plt.grid(axis='x', linestyle='--', alpha=0.2, color='white')
sns.despine(top=True, right=True)
ax.tick_params(colors='#E0E0E0')

# Adding data labels to the bars
for p in ax.patches:
    ax.annotate(f"{int(p.get_width())}",
                (p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points',
                color='#ffeb3b', fontweight='bold', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1868/2334441250.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Runs', y='Player Name', data=top_10_batters,

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Horizontal Bar Chart is the optimal choice for ranking categorical data (Player Names) against a numerical value (Runs). The horizontal layout ensures that long player names are easily readable without overlapping, and ordering them from top to bottom instantly identifies the leaders

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart clearly displays the absolute elite batters of the IPL 2025 season. We can immediately see the gap between the number one run-scorer and the rest of the top 10, indicating whether the race for the Orange Cap was closely contested or dominated by a single player.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: These top 10 players are the most marketable assets in the league. Franchises can leverage this data to maximize sponsorship deals, merchandise sales, and social media campaigns built around these specific star performers.
#
# Negative Growth/Risk: If a team relies solely on one of these top players for 40-50% of their total team runs, it indicates a massive structural flaw. If that star player loses form or gets injured, the team's winning chances will plummet.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(14, 8))
fig.patch.set_facecolor('#0d1117')
ax.set_facecolor('#0d1117')

# Scatter plot for Runs vs Strike Rate
sns.scatterplot(x='SR', y='Runs', hue='Team', data=dataset,
                palette='cool', size='4s', sizes=(50, 300),
                alpha=0.7, edgecolor='white', ax=ax)

plt.title('Multivariate Analysis: The Impact Matrix (Runs vs Strike Rate)', fontsize=18, fontweight='bold', color='white', pad=15)
plt.xlabel('Strike Rate', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)
plt.ylabel('Total Runs', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)

# Highlighting the "Elite Quadrant"
plt.axvline(x=140, color='#ff007f', linestyle='--', alpha=0.5)
plt.axhline(y=300, color='#ff007f', linestyle='--', alpha=0.5)
plt.text(180, 600, 'ELITE QUADRANT\n(High Runs, High SR)', color='#ff007f', fontsize=12, fontweight='bold', alpha=0.7)

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', frameon=False, labelcolor='white')
sns.despine(top=True, right=True)
ax.tick_params(colors='#E0E0E0')
plt.grid(True, linestyle='-', alpha=0.1, color='cyan')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Bubble Scatter Plot is perfect for Multivariate Analysis. It allows us to visualize three dimensions of data simultaneously: Strike Rate (X-axis), Total Runs (Y-axis), and the number of fours hit (Bubble Size), while the color separates the players by Team.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By adding the crosshairs (dashed lines at SR 140 and Runs 300), we instantly segment the players. The top-right quadrant identifies the "Elite" T20 players—those who score heavily and rapidly. The bottom-right shows rapid finishers (low runs, high SR), while the top-left shows anchors (high runs, low SR).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: This is a goldmine for auction strategy. Teams can visually identify and bid for players in the elite quadrant, ensuring they acquire match-winners. It also helps in scouting players in the bottom-right who might just need more batting opportunities (overs) to become elite.
#
# Negative Growth/Risk: Players stuck in the bottom-left quadrant (low runs, low SR) are actively hurting their teams. Persisting with these players wastes valuable deliveries and negatively impacts the team's net run rate and overall win probability.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(10, 10))
fig.patch.set_facecolor('#121212')

# Grouping runs by team
team_runs = dataset.groupby('Team')['Runs'].sum().sort_values(ascending=False)

# Custom highly vibrant colors for the donut chart
colors = ['#FF0055', '#00FF99', '#00CCFF', '#FFCC00', '#9900FF', '#FF6600', '#00FFCC', '#FF00CC', '#CCFF00', '#3366FF']

# Creating a Donut Chart
wedges, texts, autotexts = ax.pie(team_runs, labels=team_runs.index, autopct='%1.1f%%',
                                  startangle=90, colors=colors,
                                  wedgeprops={'width': 0.4, 'edgecolor': '#121212', 'linewidth': 2},
                                  textprops={'color': 'white', 'fontweight': 'bold', 'fontsize': 12})

plt.title('Bivariate Analysis: Franchise Batting Firepower (Total Runs per Team)', fontsize=18, fontweight='bold', color='white', pad=20)

# Adding a glowing central text
plt.text(0, 0, 'TOTAL\nRUNS', ha='center', va='center', fontsize=20, fontweight='bold', color='#E0E0E0')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Donut Chart is highly effective for displaying part-to-whole relationships. By aggregating the total runs, we can use the sleek ring design to compare the overall batting firepower of each franchise. It is cleaner than a standard pie chart and allows for central labeling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This visualization reveals the macro-level dominance of the franchises. It clearly dictates which teams had the most prolific batting lineups overall. A team with a significantly larger slice demonstrates extreme squad depth and collective scoring ability across the season.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: Benchmarking. A team can see exactly where their batting unit stands compared to the league average. High-scoring teams can use this metric to validate their batting coaches' strategies and training methods, retaining their backroom staff.
#
# Negative Growth/Risk: If a franchise holds a disproportionately small slice of this donut, their batting strategy is fundamentally broken. This insight signals a critical need for management to overhaul their scouting department and invest heavily in top-tier batters in the next auction window.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(14, 8))
fig.patch.set_facecolor('#0a0a0a')
ax.set_facecolor('#0a0a0a')

# Grouping boundaries by team
team_boundaries = dataset.groupby('Team')[['4s', '6s']].sum().sort_values(by='6s', ascending=False)

# Stacked Bar Chart for Boundaries
team_boundaries.plot(kind='bar', stacked=True, ax=ax,
                     color=['#00e676', '#d500f9'], edgecolor='#0a0a0a', linewidth=1.5)

plt.title('Bivariate Analysis: The Boundary Breakdown (4s vs 6s by Team)', fontsize=18, fontweight='bold', color='white', pad=15)
plt.xlabel('Franchise', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)
plt.ylabel('Total Count of Boundaries', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)

plt.legend(['Fours (4s)', 'Sixes (6s)'], frameon=False, labelcolor='white', fontsize=12)
plt.grid(axis='y', linestyle='-.', alpha=0.2, color='#00e676')
sns.despine(top=True, right=True)
ax.tick_params(colors='#E0E0E0', rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Stacked Bar Chart is the best way to compare absolute totals (total boundaries) across categories (Teams) while simultaneously breaking down the composition of those totals (the ratio of Fours to Sixes).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can instantly identify the tactical approach of different franchises. Teams with a massive purple block rely heavily on sheer power hitting and clearing the ropes (6s). Teams with a dominant green block prioritize finding gaps, placement, and running between the wickets to accumulate boundaries (4s).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: This dictates home-ground curation strategy. A team heavily reliant on 6s should curate flat pitches with shorter boundaries at their home stadium to maximize their specific squad strength, directly leading to more home wins.
#
# Negative Growth/Risk: A team with a very low six-hitting ratio will struggle massively in high-pressure run chases where the required run rate spikes. Inability to hit sixes in modern T20s is a severe tactical handicap that leads to tournament elimination.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(14, 8))
fig.patch.set_facecolor('#181824')
ax.set_facecolor('#181824')

# Boxplot to check batting average consistency across teams
sns.boxplot(x='Team', y='AVG', data=dataset, palette='Set3',
            boxprops=dict(alpha=0.7, edgecolor='white', linewidth=2),
            whiskerprops=dict(color='white', linewidth=1.5),
            capprops=dict(color='white', linewidth=1.5),
            medianprops=dict(color='#ff0055', linewidth=3), ax=ax)

# Adding a stripplot to show individual data points on top of the boxes
sns.stripplot(x='Team', y='AVG', data=dataset, color='#00e5ff', alpha=0.6, size=6, jitter=True, ax=ax)

plt.title('Bivariate Analysis: Batting Average Consistency by Team', fontsize=18, fontweight='bold', color='white', pad=15)
plt.xlabel('Team', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)
plt.ylabel('Batting Average', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)

plt.grid(axis='y', linestyle='--', alpha=0.2, color='white')
sns.despine(top=True, right=True)
ax.tick_params(colors='#E0E0E0')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1868/1464159807.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Team', y='AVG', data=dataset, palette='Set3',

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Boxplot overlaid with a Strip Plot provides a comprehensive view of categorical data distributions. The boxplot shows the median, interquartile range (IQR - the middle 50% of players), and spread, while the strip plot reveals the exact position of every single player's average, making it easy to spot outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe which teams possess a consistent batting lineup versus heavily reliant ones. A compact box indicates that most batters in that team have similar averages (consistency). A very tall box, or a box with high floating points (outliers), shows a team relying on one or two star players while the rest of the lineup fails to contribute meaningfully.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: Teams with high medians and tight boxes demonstrate excellent squad depth. This proves that their scouting and player development strategies are highly successful and should be replicated in future seasons.
#
# Negative Growth/Risk: A franchise with a very low median or extremely wide spread suffers from a brittle batting order. This highlights a negative growth trajectory where a few early wickets inevitably lead to a batting collapse.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 9))
fig.patch.set_facecolor('#050510')
ax.set_facecolor('#050510')

# 2D Kernel Density Estimate (Contour / Topographic Plot)
# This maps the "gravity center" of player performances
sns.kdeplot(x=dataset['SR'], y=dataset['AVG'], cmap='mako',
            fill=True, thresh=0.05, levels=12, alpha=0.9, ax=ax)

# Layering a subtle scatter plot on top to see the exact player positions
sns.scatterplot(x=dataset['SR'], y=dataset['AVG'], color='#00ffcc',
                s=30, alpha=0.6, edgecolor='white', ax=ax)

plt.title('Bivariate Analysis: Performance Density Contour (AVG vs SR)', fontsize=18, fontweight='bold', color='white', pad=15)
plt.xlabel('Strike Rate (Pace of Scoring)', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)
plt.ylabel('Batting Average (Consistency)', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)

# Highlighting the core density zone
plt.axvline(x=130, color='#ff007f', linestyle='--', alpha=0.4)
plt.axvline(x=160, color='#ff007f', linestyle='--', alpha=0.4)
plt.text(135, dataset['AVG'].max() - 5, 'CORE PLAYER\nDENSITY ZONE', color='#ff007f', fontweight='bold', fontsize=12)

plt.grid(True, linestyle='-', alpha=0.05, color='white')
sns.despine(top=True, right=True)
ax.tick_params(colors='#E0E0E0')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A 2D Density Contour Plot (KDE) acts like a topographic map. Instead of just showing scattered dots where data overlaps and becomes unreadable, it uses glowing color gradients to show the exact "gravity center" where the highest density of players sits. It is one of the most professional ways to view bivariate distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The brightest/lightest blue areas reveal the league's true baseline. We can instantly see that the vast majority of T20 batters naturally gravitate towards a specific zone (likely an average of 20-30 and a strike rate of 130-140). Anyone mapped outside this glowing contour core—especially towards the top right—is statistically a rare outlier.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: This establishes an undeniable mathematical baseline for player salaries. If a player sits squarely inside the brightest core, they are a "replacement-level" player. Franchises can use this to avoid overpaying for average talent, reserving premium budgets only for players who sit outside the core on the top-right.
#
# Negative Growth/Risk: Scouting players entirely from the bottom-left of this contour map leads to negative growth. Those players perform below the tournament's standard baseline, meaning their inclusion in the playing XI mathematically decreases the team's expected run total.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(14, 8))
fig.patch.set_facecolor('#120a17')
ax.set_facecolor('#120a17')

# Feature Engineering: Calculating Runs from Boundaries vs Running
dataset_calc = dataset.copy()
dataset_calc['Boundary_Runs'] = (dataset_calc['4s'] * 4) + (dataset_calc['6s'] * 6)
dataset_calc['Running_Runs'] = dataset_calc['Runs'] - dataset_calc['Boundary_Runs']

# Getting top 10 highest run scorers
top_10 = dataset_calc.nlargest(10, 'Runs')

# Stacked Bar for Run Composition
ax.bar(top_10['Player Name'], top_10['Boundary_Runs'], label='Runs from Boundaries (4s & 6s)', color='#ff0055', edgecolor='white')
ax.bar(top_10['Player Name'], top_10['Running_Runs'], bottom=top_10['Boundary_Runs'], label='Runs from Running (1s, 2s, 3s)', color='#00e5ff', edgecolor='white')

plt.title('Multivariate Analysis: Run Composition of Top 10 Batters (Boundaries vs Running)', fontsize=18, fontweight='bold', color='white', pad=15)
plt.xlabel('Player Name', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)
plt.ylabel('Total Runs', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)

plt.xticks(rotation=45, ha='right', color='#E0E0E0', fontweight='bold')
plt.yticks(color='#E0E0E0')
ax.legend(frameon=False, labelcolor='white', fontsize=12, loc='upper right')

plt.grid(axis='y', linestyle=':', alpha=0.3, color='white')
sns.despine(top=True, right=True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Composition Stacked Bar Chart is perfect for taking a single total metric (Total Runs) and breaking it down into its constituent parts. By feature engineering the data to separate boundary runs from running runs, this chart uniquely visuals how a player achieves their score, not just what they scored.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart profiles a player's physical fitness and batting style. A massive pink section indicates a pure power-hitter who relies on clearing the ropes. A large cyan section indicates a highly fit, agile player who excels at gap-placement and strike rotation (running hard between the wickets).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: This dictates opening partnership strategies. A team can use this to perfectly pair a pure power-hitter (huge pink bar) with a strike-rotator (huge cyan bar). This ensures the scoreboard keeps moving regardless of whether boundaries are being hit, maximizing the total team score.
#
# Negative Growth/Risk: If a player has a huge boundary run count but almost zero running runs, it implies poor physical fitness or an inability to rotate the strike against spin bowling. On large grounds with long boundaries, this player will become a massive liability, stalling the innings and creating negative momentum.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(14, 8))
fig.patch.set_facecolor('#0d1117')
ax.set_facecolor('#0d1117')

# Calculating the Max SR and Average SR per team to find the "Dependency Gap"
team_sr = dataset.groupby('Team')['SR'].agg(['max', 'mean']).sort_values(by='mean')
teams = team_sr.index
max_sr = team_sr['max']
mean_sr = team_sr['mean']

# Creating a Dumbbell Plot (Gap Analysis)
for i in range(len(teams)):
    # The connecting line
    ax.plot([mean_sr[i], max_sr[i]], [i, i], color='#555555', linewidth=3, zorder=1)
    # The average team SR dot
    ax.scatter(mean_sr[i], i, color='#00ffcc', s=150, zorder=2, label='Team Average SR' if i==0 else "")
    # The highest individual SR dot
    ax.scatter(max_sr[i], i, color='#ffeb3b', s=150, zorder=3, label='Highest Individual SR' if i==0 else "")

plt.title('Bivariate Analysis: The Squad Dependency Gap (Team Avg SR vs Top Player SR)', fontsize=18, fontweight='bold', color='white', pad=15)
plt.xlabel('Strike Rate', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)
plt.ylabel('Franchise', fontsize=14, fontweight='bold', color='#E0E0E0', labelpad=10)

plt.yticks(range(len(teams)), teams, color='#E0E0E0', fontweight='bold')
plt.xticks(color='#E0E0E0')
ax.legend(frameon=False, labelcolor='white', fontsize=12, loc='lower right')

plt.grid(axis='x', linestyle='--', alpha=0.2, color='white')
sns.despine(top=True, right=True, left=True)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1868/2371942135.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.plot([mean_sr[i], max_sr[i]], [i, i], color='#555555', linewidth=3, zorder=1)
# /tmp/ipykernel_1868/2371942135.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.scatter(mean_sr[i], i, color='#00ffcc', s=150, zorder=2, label='Team Average SR' if i==0 else "")
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Dumbbell Plot (also known as a connected dot plot) is the absolute best visualization for showing the "gap" or distance between two data points across different categories. It is far cleaner and more impactful than placing two standard bars next to each other, giving a high-end analytical look.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart reveals how heavily a team relies on a single explosive player. The cyan dot represents the average pace of the whole team, while the yellow dot is their fastest-scoring player. A massive grey line connecting them indicates that one specific star player is carrying the team's strike rate, while the rest of the squad bats slowly. A short line indicates a highly balanced squad where everyone attacks equally.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: Teams with short gaps and high cyan dots prove they have built a cohesive, deeply threatening batting unit that doesn't rely on one person. This validates their squad-building approach and attracts sponsors who want a consistently winning brand.
#
# Negative Growth/Risk: A massive gap (long grey line) is a huge red flag for squad fragility. If that one yellow-dot player gets out early, the team's scoring rate will immediately collapse to the cyan dot, resulting in un-defendable totals. Management must urgently trade for better middle-order batters to close this gap.

# %% [markdown]
# #### Chart - 11 - Heatmap

# %%
# Correlation Heatmap visualization code

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 10))
fig.patch.set_facecolor('#000000')
ax.set_facecolor('#000000')

# Selecting only numerical columns for correlation
numerical_data = dataset.select_dtypes(include=[np.number])
correlation_matrix = numerical_data.corr()

# Creating a mask to hide the upper triangle for a cleaner look
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Heatmap with an intense, dark-themed colormap
sns.heatmap(correlation_matrix, mask=mask, annot=True, fmt=".2f",
            cmap='inferno', vmin=-1, vmax=1,
            cbar_kws={"shrink": .8}, linewidths=1, linecolor='#222222', ax=ax)

plt.title('Multivariate Analysis: Correlation Matrix of Batting Metrics', fontsize=18, fontweight='bold', color='white', pad=20)

plt.xticks(rotation=45, ha='right', color='#E0E0E0', fontweight='bold')
plt.yticks(rotation=0, color='#E0E0E0', fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Correlation Heatmap is the absolute standard for Multivariate Analysis when attempting to find relationships across all numerical variables at once. It uses color intensity to represent the strength and direction of the linear relationships, making complex multi-variable interactions instantly readable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap reveals exactly which metrics drive run-scoring. For example, we typically see a near-perfect positive correlation between Runs and Balls Faced (BF), and very strong correlations between Runs and boundaries (4s, 6s). Interestingly, we can observe whether Strike Rate (SR) has any correlation with Average (AVG), which often reveals if aggressive players tend to get out faster.

# %% [markdown]
# #### Chart - 12 - Pair Plot

# %%
# Pair Plot visualization code

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')

# Selecting key performance metrics to avoid extreme clutter
# (plotting all columns creates an unreadable, slow-loading grid)
key_metrics = ['Runs', 'AVG', 'SR', '4s', '6s', 'Team']
pairplot_data = dataset[key_metrics]

# Creating the pairplot with a vibrant, neon-themed palette
pair_plot = sns.pairplot(pairplot_data, hue='Team', palette='husl',
                         plot_kws={'alpha': 0.7, 's': 40, 'edgecolor': 'black'},
                         diag_kws={'alpha': 0.7, 'edgecolor': 'black'})

# Adjusting the background color of the grid to match our dark theme
pair_plot.fig.patch.set_facecolor('#121212')
for ax in pair_plot.axes.flatten():
    if ax is not None:
        ax.set_facecolor('#121212')
        ax.tick_params(colors='#E0E0E0')
        ax.xaxis.label.set_color('#E0E0E0')
        ax.yaxis.label.set_color('#E0E0E0')

# Adding a comprehensive title
pair_plot.fig.suptitle('Multivariate Analysis: Master Pair Plot of Key Batting Metrics',
                       fontsize=18, fontweight='bold', color='white', y=1.02)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Pair Plot is the ultimate exploratory tool for Multivariate Analysis. It creates a comprehensive matrix that plots every selected numerical variable against every other numerical variable in a single view. The diagonal axes display the univariate distribution (density shapes) of each metric, while the off-diagonals display bivariate scatter plots, allowing us to spot multi-variable relationships and team-based clusters simultaneously.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The grid provides a macro-level summary of the entire dataset. We can observe strict linear relationships (such as Total Runs moving perfectly in tandem with 4s and 6s). However, the intersections involving Strike Rate (SR) and Average (AVG) show a wide, scattered variance. This visually confirms that high run accumulators do not naturally equate to fast scorers. The color clustering (hue by Team) also reveals if specific franchises dominate certain metric intersections.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Implement Data-Driven Recruitment: Move away from relying solely on traditional metrics like aggregate runs. Instead, utilize the identified "Elite Quadrant" criteria—targeting players who maintain a high strike rate (SR > 145+) while maintaining consistent scoring averages. This ensures the acquisition of high-impact match-winners rather than just volume accumulators.
#
# Optimize Squad Depth & Balance: Avoid over-investing in a single marquee player. Our analysis shows that a heavy reliance on one batter creates "squad fragility." I suggest allocating the salary budget to create a deep, balanced batting lineup where boundary-hitting and strike-rotation capabilities are distributed across all players, ensuring resilience against early wicket losses.
#
# Adopt Specialized Role Profiling: Use the findings to scout and train players for specific game phases. For instance, identify "clutch" finishers—those who show high "Not Out" counts and high strike rates—to close out tight matches. Pair pure power-hitters with agile strike-rotators to ensure constant scoreboard movement throughout the innings.
#
# Dynamic Auction & Contract Strategy: Leverage the "Dumbbell Gap Analysis" to identify franchises with poor batting unity and target their high-performing individual players for recruitment. Use comparative strike-rate data to avoid overpaying for "name-brand" players whose efficiency metrics do not justify their market cost, thereby maximizing the franchise's total Return on Investment (ROI).

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
